# %%
from genepy.utils import helper as h

from taigapy import TaigaClient
from celligner import Celligner
tc = TaigaClient()
from bokeh.plotting import output_notebook
#autoreload
# %load_ext autoreload
# %autoreload 2
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1178">Loading BokehJS ...</span>
#     </div>

# %%
# load from taiga public (figshare link)
# load internal expression,
CCLE_expression = tc.get(name='internal-21q3-fe4c',
                         file='CCLE_expression_full')  # https://depmap.org/portal/download/

# load  TCGA expression
# this dataset was generated from  ,using this script:
TCGA_expression = tc.get(name='celligner-input-9827',
                         file='tumor_expression')
# Out:
# No dataset version provided. Using version 16.
# No dataset version provided. Using version 1.

# %%
# subset gene names to ensembl ids only
CCLE_expression = CCLE_expression[CCLE_expression.columns[:-92]]
CCLE_expression.columns = list(map(lambda x: x.split(
    ' (')[1][:-1] if ' (' in x else x, CCLE_expression.columns))

common = set(CCLE_expression.columns).intersection(
    set(TCGA_expression.columns))
CCLE_expression = CCLE_expression[list(common)]
TCGA_expression = TCGA_expression[list(common)]

# %%
my_alligner = Celligner(snn_kwargs={"neighbor_num": 34, "min_shared_neighbor_proportion": 1/15,}, make_plots=True)

my_alligner.fit(TCGA_expression.iloc[:500])
# Out:
# fetching gene names from biomart cache
# using only usefull genes
# looking at 500 samples.
# found 29593 common genes
# creating a fit dataset..
# reducing dimensionality...
# clustering...
#   <div class="bk-root" id="fb34602d-773e-4ae5-b5f1-ab6a312c009e" data-root-id="4652"></div>
# doing differential expression analysis on the clusters
# running differential expression on 3 clusters
# running limmapy on the samples
# you need to have R installed with the limma library installed
# 3.2.1
# done

# %%
my_alligner.addToFit(TCGA_expression.iloc[500:2000])
# Out:
# looking at 1500 samples.
# found 29593 common genes
# adding to fit dataset..
# reducing dimensionality...
# clustering...
#   <div class="bk-root" id="fa134c23-1f3b-42c3-98aa-a3e5a9f7f1bb" data-root-id="4971"></div>
# doing differential expression analysis on the clusters
# running differential expression on 18 clusters
# running limmapy on the samples
# you need to have R installed with the limma library installed
# 3.2.1
# done

# %%
my_alligner.predict(CCLE_expression.iloc[:200])
# Out:
# found 29593 common genes
# adding to predict..
# reducing dimensionality...
# clustering..
# doing differential expression analysis on the clusters..
# running differential expression on 3 clusters
# running limmapy on the samples
# you need to have R installed with the limma library installed
# 3.2.1
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in from_object(cls, obj)
#     367         try:
# --> 368             mv = memoryview(obj)
#     369             res = cls.from_memoryview(mv)
#
# TypeError: memoryview: a bytes-like object is required, not 'tuple'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                      Traceback (most recent call last)
# <ipython-input-42-924c8cd20f20> in <module>
# ----> 1 my_alligner.predict(CCLE_expression.iloc[:200])
#
# ~/celligner/celligner/__init__.py in predict(self, X_pression, annotations, return_predict)
#     322                                              data=self.predict_input.var(axis=1))
#     323     else:
# --> 324       differential_genes = runDiffExprOnCluster(self.predict_input, self.predict_clusters)
#     325       differential_genes.log2FoldChange = differential_genes.log2FoldChange.abs()
#     326       # need enough genes to be significant
#
# ~/celligner/celligner/__init__.py in runDiffExprOnCluster(expression, clustered, clust_covariates, pvalue_threshold)
#      80   # running limmapy
#      81   print("running limmapy on the samples")
# ---> 82   res = limma.limmapy().lmFit(data, design_matrix).eBayes(trend=False).topTable(
#      83       number=1_000_000_000,).iloc[:,len(clusts):]
#      84   return res.sort_values(by='F')
#
# ~/celligner/celligner/limma.py in lmFit(self, count_matrix, design_matrix, **kwargs)
#      50     """
#      51     with localconverter(ro.default_converter + pandas2ri.converter):
# ---> 52       count_matrix = pandas2ri.py2rpy(count_matrix.astype(int))
#      53       design_matrix = pandas2ri.py2rpy(design_matrix.astype(int))
#      54     self.fit = limma.lmFit(count_matrix, design_matrix, **kwargs)
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in py2rpy_pandasdataframe(obj)
#      53     for name, values in obj.iteritems():
#      54         try:
# ---> 55             od[name] = conversion.py2rpy(values)
#      56         except Exception as e:
#      57             warnings.warn('Error while trying to convert '
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in py2rpy_pandasseries(obj)
#     163     if obj.ndim == 1:
#     164         res.do_slot_assign('names',
# --> 165                            StrVector(tuple(str(x) for x in obj.index)))
#     166     else:
#     167         res.do_slot_assign('dimnames',
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/robjects/vectors.py in __init__(self, obj)
#     382
#     383     def __init__(self, obj):
# --> 384         super().__init__(obj)
#     385         self._add_rops()
#     386
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in __init__(self, obj)
#     286             super().__init__(obj)
#     287         elif isinstance(obj, collections.abc.Sized):
# --> 288             super().__init__(type(self).from_object(obj).__sexp__)
#     289         else:
#     290             raise TypeError('The constructor must be called '
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in from_object(cls, obj)
#     370         except (TypeError, ValueError):
#     371             try:
# --> 372                 res = cls.from_iterable(obj)
#     373             except ValueError:
#     374                 msg = ('The class methods from_memoryview() and '
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      38 def _cdata_res_to_rinterface(function):
#      39     def _(*args, **kwargs):
# ---> 40         cdata = function(*args, **kwargs)
#      41         # TODO: test cdata is of the expected CType
#      42         return _cdata_to_rinterface(cdata)
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in from_iterable(cls, iterable, populate_func)
#     317             if populate_func is None:
#     318                 cls._populate_r_vector(iterable,
# --> 319                                        r_vector)
#     320             else:
#     321                 populate_func(iterable, r_vector)
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in _populate_r_vector(cls, iterable, r_vector)
#     300                                   r_vector,
#     301                                   cls._R_SET_VECTOR_ELT,
# --> 302                                   cls._CAST_IN)
#     303
#     304     @classmethod
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in _populate_r_vector(iterable, r_vector, set_elt, cast_value)
#     237 def _populate_r_vector(iterable, r_vector, set_elt, cast_value):
#     238     for i, v in enumerate(iterable):
# --> 239         set_elt(r_vector, i, cast_value(v))
#     240
#     241
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in _as_charsxp_cdata(x)
#     430         return x.__sexp__._cdata
#     431     else:
# --> 432         return conversion._str_to_charsxp(x)
#     433
#     434
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _str_to_charsxp(val)
#     133         s = rlib.R_NaString
#     134     else:
# --> 135         cchar = _str_to_cchar(val)
#     136         s = rlib.Rf_mkCharCE(cchar, _CE_DEFAULT_VALUE)
#     137     return s
#
# ~/miniconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _str_to_cchar(s, encoding)
#     112 def _str_to_cchar(s: str, encoding: str = 'utf-8'):
#     113     # TODO: use isStrinb and installTrChar
# --> 114     b = s.encode(encoding)
#     115     return ffi.new('char[]', b)
#     116
#
# KeyboardInterrupt:
